# %%
from random import randint
h = 5
w = 6
matrix = []
for i in range(h):
    row = []
    for j in range(w):
        n = randint(-99,99)
        row.append(n)
        print("%4d" % n, end="")
    matrix.append(row)
    print()
# Out:
#    8  72 -78 -57  64 -38
#  -35   5 -27 -22  -9 -63
#   -6  31 -46   5 -48 -98
#   29  75  99 -11 -47 -79
#   67  42 -35  82  34 -71

# %%
print(float("nan"), float("inf"))
# Out:
# nan inf

# %%
new_matrix = []
for i in range(len(matrix)):
    row = []
    for j in range(len(matrix[0])):
      if matrix[i][j] > 50:
        n = matrix[i][j]
      else:
        n = "*"
      row.append(n)
    new_matrix.append(row)

for i in new_matrix:
  for j in i:
    print("%4s" %j, end = "")
  print()
# Out:
#    *  72   *   *  64   *
#    *   *   *   *   *   *
#    *   *   *   *   *   *
#    *  75  99   *   *   *
#   67   *   *  82   *   *

# %%
lstv = [[0, 'numpy'], [1, 'pandas'], [2, 'time'], [3, 'random']]

i = 0
while i < len(lstv):
    if i % 2 == 0:
        lstv[i] = [str(123) + f"{i}"] 
    i +=1
print(lstv)
# Out:
# [['1230'], [1, 'pandas'], ['1232'], [3, 'random']]

# %%
s = input("enter s: ")
lowecase_letters = 0
capital_letters = 0
for char in s:
    if "a" <= char <= "z":
        lowecase_letters += 1
    elif "A" <= char <= "Z":
        capital_letters += 1
print(f"Заглавными: {capital_letters}. Прописными: {lowecase_letters}")
# Out:
# enter s: HejcirjcieFmfkDFJFJDJXKC FJD Ccd ddghfc
# Заглавными: 16. Прописными: 20

# %%
f = 'I\ntwo - 2 - II\nthree - 3 - III\nfour - 4 - IV\nfive - 5 - V\n'
ru = ["один", "два", "три", "четыре", "пять"]

#i = 0
#for line in f:
#    l = f.split("-")
#   
#       l = ru[i]
#    i += 1
#print(l)


l = (line.split("-") for line in f)
tuple(l)
# Out:
# (['I'],
#  ['\n'],
#  ['t'],
#  ['w'],
#  ['o'],
#  [' '],
#  ['', ''],
#  [' '],
#  ['2'],
#  [' '],
#  ['', ''],
#  [' '],
#  ['I'],
#  ['I'],
#  ['\n'],
#  ['t'],
#  ['h'],
#  ['r'],
#  ['e'],
#  ['e'],
#  [' '],
#  ['', ''],
#  [' '],
#  ['3'],
#  [' '],
#  ['', ''],
#  [' '],
#  ['I'],
#  ['I'],
#  ['I'],
#  ['\n'],
#  ['f'],
#  ['o'],
#  ['u'],
#  ['r'],
#  [' '],
#  ['', ''],
#  [' '],
#  ['4'],
#  [' '],
#  ['', ''],
#  [' '],
#  ['I'],
#  ['V'],
#  ['\n'],
#  ['f'],
#  ['i'],
#  ['v'],
#  ['e'],
#  [' '],
#  ['', ''],
#  [' '],
#  ['5'],
#  [' '],
#  ['', ''],
#  [' '],
#  ['V'],
#  ['\n'])

# %%
worker = ["Sasha", "Smirnov", 75000.0, 3]


experience = worker[-1]
if experience < 2:
    position = "junior"
elif 2 <= experience <=5:
    position = "middle"
else:
    position = "senior"

status = f"{worker[0]} {worker[1]} is {position}"
print(status)
# Out:
# Sasha Smirnov is middle

# %%
# a = [[1,2,3],["a","b","c"],["alpha", "beta", "gamma"]]
names = ["Никита", "Дарья", "Екатерина", "Дмитрий"]
ages = [32, 28, 37, 53]
gender = ["Мужчина", "Женщина", "Женщина", "Мужчина"]
zipped = zip(names, ages, gender)
zipped_list = list(zipped)
print(zipped_list)



import random
N, M = 3, 4
m = []
for i in range(N):
    b = []
    for j in range(M):
        b.append(random.randint(1,99))
    m.append(b)
m
# Out:
# [('Никита', 32, 'Мужчина'), ('Дарья', 28, 'Женщина'), ('Екатерина', 37, 'Женщина'), ('Дмитрий', 53, 'Мужчина')]
# [[34, 17, 17, 95], [37, 16, 79, 15], [75, 18, 54, 73]]

# %%
squad = {1: 'alpha', 2: 'beta', 3: 'gamma', 4: 'delta', 5: 'epsilon'}
for i, key in enumerate(squad):
  if i % 2 == 0:
    print(key, end =" ")
    print(squad[key], end =" ")
# Out:
# 1 alpha 3 gamma 5 epsilon

# %%
matrix = [[1,2,3],[4,5,6],[7,8,9]]
[(e, e2, e3) for e, e2, e3 in matrix]


matrix2 = []
for e,e2,e3 in matrix:
    e = e*10
    e2 = e2*"*"
    e3 = e3*e3
    matrix2.append((e, e2, e3))

# print(matrix2)

#for i in matrix:
#  for g in i:
      # print(g)


al = {"alpha":1,"beta":2,"gamma":3,"delta":4}

for i, key in enumerate(al):
    if i % 2 == 0:
        print(key, end = " ")
        print(al[key], end = " ")
#print(al)
# Out:
# alpha 1 gamma 3

# %%
text = "Генераторные выражения вычисляются лениво, что означает, что они генерируют и возвращают каждое значение только тогда, когда генератор повторяется. Это может пригодиться при переборе больших наборов данных, без создания дубликатов набора данных в памяти"

a =[[1,2],[3,4],[5,6]]

for a[i] in a:
  print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d483cadd936f> in <module>()
#       3 a =[[1,2],[3,4],[5,6]]
#       4
# ----> 5 for a[i] in a:
#       6   print(i)
#       7
#
# NameError: name 'i' is not defined

# %%
from types import SimpleNamespace
numbers = [1, 2, 3, 4, 5]
list_a = [-2, -1, 0, 1, 2, 3, 4, 5]


words = ["python", "scala", "java", "c++"]

#print(sum(x for x in range(5)))

a = map(int, "1234567890")
next(a)
#a = range(10)       
#list(a)

#[i[1] for i in enumerate(range(10)) if 3 < i[1] < 8]
# [i[1] for i in enumerate(list_a) if 1 <= i[0] <= 3]
# Out:
# 1

# %%
population = {"Shanghai": 24256800, "Karachi": 23500000, "Beijing": 21516000, "Delhi": 16787941}
for val in sorted(population.values()):
  print(val)
# Out:
# 16787941
# 21516000
# 23500000
# 24256800

# %%
# изменение значений в словаре
new_bots = []
for skill_bots in range (0,30):
    bot = {'color': 'green', 'points': 5, 'speed': 'slow'}
    new_bots.append(bot)
i = 0
for bot in new_bots:
    if i % 2 == 0:
        bot['color'] = 'yellow'
        bot['speed'] = 'medium'
        bot['points'] = 10
    i += 1

for i in enumerate(new_bots):
    print(i)
# Out:
# (0, {'color': 'yellow', 'points': 10, 'speed': 'medium'})
# (1, {'color': 'green', 'points': 5, 'speed': 'slow'})
# (2, {'color': 'yellow', 'points': 10, 'speed': 'medium'})
# (3, {'color': 'green', 'points': 5, 'speed': 'slow'})
# (4, {'color': 'yellow', 'points': 10, 'speed': 'medium'})
# (5, {'color': 'green', 'points': 5, 'speed': 'slow'})
# (6, {'color': 'yellow', 'points': 10, 'speed': 'medium'})
# (7, {'color': 'green', 'points': 5, 'speed': 'slow'})
# (8, {'color': 'yellow', 'points': 10, 'speed': 'medium'})
# (9, {'color': 'green', 'points': 5, 'speed': 'slow'})
# (10, {'color': 'yellow', 'points': 10, 'speed': 'medium'})
# (11, {'color': 'green', 'points': 5, 'speed': 'slow'})
# (12, {'color': 'yellow', 'points': 10, 'speed': 'medium'})
# (13, {'color': 'green', 'points': 5, 'speed': 'slow'})
# (14, {'color': 'yellow', 'points': 10, 'speed': 'medium'})
# (15, {'color': 'green', 'points': 5, 'speed': 'slow'})
# (16, {'color': 'yellow', 'points': 10, 'speed': 'medium'})
# ...

# %%
nums = {1: "one", 2: "two", 3: "three"}


v_nums = []
for elm in nums:
    v_nums.append(elm)
v_nums # ['one', 'two', 'three']
# Out:
# [1, 2, 3]

# %%
def f_gen(n):
    i = 1
    for elm in range(1,n):
        yield elm**2 + i
        i += 1

gen_a = f_gen(5)
gen_a.__next__()
# Out:
# 2

# %%
gen_a.__next__()
# Out:
# 6

# %%
gen_a.__next__()
# Out:
# 12

# %%
gen_a.__next__()
# Out:
# 20

# %%
gen_a.__next__()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-5-908453c1036b> in <module>()
# ----> 1 gen_a.__next__()
#
# StopIteration:
